# %%
import numpy as np
import math
from tqdm.notebook import tqdm
from functools import cache
import copy

import heapq

import matplotlib.pyplot as plt

# %%
with open("input_day_23.txt") as f:
    text = f.read()


test = False
if test:
    text = r"""
#.#####################
#.......#########...###
#######.#########.#.###
###.....#.>.>.###.#.###
###v#####.#v#.###.#.###
###.>...#.#.#.....#...#
###v###.#.#.#########.#
###...#.#.#.......#...#
#####.#.#.#######.#.###
#.....#.#.#.......#...#
#.#####.#.#.#########v#
#.#...#...#...###...>.#
#.#.#v#######v###.###v#
#...#.>.#...>.>.#.###.#
#####v#.#.###v#.#.###.#
#.....#...#...#.#.#...#
#.#########.###.#.#.###
#...###...#...#...#.###
###.###.#.###v#####v###
#...#...#.#.>.>.#.>.###
#.###.###.#.###.#.#v###
#.....###...###...#...#
#####################.#
"""

text = text.strip()

# %%
G_strs = text.split("\n")
R = len(G_strs)
C = len(G_strs[0])

G = []
for r_str in G_strs:
    G.append([])
    for c in range(len(r_str)):
        G[-1].append(r_str[c])

print(R, C)
# Out:
# 141 141

# %%
num_states_considered = 0
longest_dist = -1

min_curr_acc_heat_losses = {}

q = []
heapq.heapify(q)

# pos, visited_poses
first_state = ((0,1), set((0,1)))

heapq.heappush(q, first_state)

while len(q) > 0:

    current_state = heapq.heappop(q)

    curr_pos, curr_visited_poses = current_state
    r, c = curr_pos
    
    num_states_considered += 1

    if num_states_considered % 10000 == 0:
        print(f"    {num_states_considered} states considered, longest_dist: {longest_dist-2}")

    if current_state[0] == (R-1, C-2):
        longest_dist = max(longest_dist, len(curr_visited_poses))
        continue

    for next_dir in [(-1, 0), (1, 0), (0, -1), (0, 1)]:

        if G[r][c] == "^" and next_dir != (-1,0):
            continue
        if G[r][c] == ">" and next_dir != (0,1):
            continue
        if G[r][c] == "<" and next_dir != (0,-1):
            continue
        if G[r][c] == "v" and next_dir != (1,0):
            continue

        next_pos = (r + next_dir[0], c + next_dir[1])

        if G[next_pos[0]][next_pos[1]] == "#":
            continue

        if next_pos in curr_visited_poses:
            continue
    
        next_visited_poses = set(curr_visited_poses)
        next_visited_poses.add(next_pos)

        next_state = (next_pos, next_visited_poses)
        heapq.heappush(q, next_state)

print("num states checked:", num_states_considered)

print(f"part 1:    all states exhausted, longest_dist = {longest_dist-2}")
# Out:
#     10000 states considered, longest_dist: -3
#     20000 states considered, longest_dist: -3
#     30000 states considered, longest_dist: -3
#     40000 states considered, longest_dist: -3
#     50000 states considered, longest_dist: -3
#     60000 states considered, longest_dist: -3
#     70000 states considered, longest_dist: -3
#     80000 states considered, longest_dist: -3
#     90000 states considered, longest_dist: -3
#     100000 states considered, longest_dist: -3
#     110000 states considered, longest_dist: -3
#     120000 states considered, longest_dist: -3
#     130000 states considered, longest_dist: -3
#     140000 states considered, longest_dist: -3
#     150000 states considered, longest_dist: -3
#     160000 states considered, longest_dist: -3
# num states checked: 162037
# part 1:    all states exhausted, longest_dist = 2386

# %%
intersection_points = set()
intersection_points.add((0,1))
intersection_points.add((R-1,C-2))

teleportations = {}

for r in range(R):
    for c in range(C):
        if G[r][c] == "#":
            continue
        num_open = 0
        for d in [(1,0), (-1,0), (0,1), (0,-1)]:
            if not (0 <= r+d[0] < R and 0 <= c+d[1] < C):
                continue
            if (   G[r+d[0]][c+d[1]] == "."
                or G[r+d[0]][c+d[1]] == "<"
                or G[r+d[0]][c+d[1]] == ">"
                or G[r+d[0]][c+d[1]] == "^"
                or G[r+d[0]][c+d[1]] == "v"):
                    num_open += 1
        if num_open > 2:
            #print("adding")
            intersection_points.add((r, c))
        #print(r,c,num_open)
        

intersection_points
# Out:
# {(0, 1),
#  (5, 7),
#  (5, 59),
#  (7, 89),
#  (11, 109),
#  (15, 41),
#  (29, 13),
#  (29, 107),
#  (33, 63),
#  (35, 33),
#  (35, 81),
#  (41, 137),
#  (55, 57),
#  (55, 103),
#  (57, 17),
#  (57, 137),
#  (59, 31),
#  (59, 75),
#  (79, 109),
#  (79, 137),
#  (83, 57),
#  (83, 87),
#  (87, 11),
#  (89, 43),
#  (101, 41),
#  (103, 127),
#  (105, 87),
#  (105, 99),
#  (107, 53),
#  (111, 17),
#  (123, 113),
#  (125, 63),
#  (125, 83),
#  (131, 137),
#  (133, 39),
#  (140, 139)}

# %%
def count_adjacent_intersections(pos):
    #print("counting adjacent intersections", pos)
    num_adjacent_intersections = 0
    for rr, cc in [(1,0), (-1,0), (0,1), (0,-1)]:
        if (pos[0]+rr, pos[1]+cc) in intersection_points:
            num_adjacent_intersections += 1
            #print("found one at", (pos[0]+rr, pos[1]+cc))
    return num_adjacent_intersections

# %%
teleportations = {}
for r in range(R):
    for c in range(C):
        #if (r,c) != (13,6):
        #    continue

        if (count_adjacent_intersections((r,c)) == 1 and 
            (G[r][c] == "." or G[r][c] == "<" or G[r][c] == ">" or G[r][c] == "^" or G[r][c] == "v")):

            #print("starting path finding", r, c)


            num_steps = 0

            curr_teleport_start = (r, c)
            curr_r, curr_c = r, c
            curr_G = copy.deepcopy(G)
            curr_G[curr_r][curr_c] = "#"
            while True:
                #print("in loop", curr_r, curr_c)
                for rr, cc in [(1,0), (-1,0), (0,1), (0,-1)]:
                    if not (0 <= curr_r + rr < R and 0 <= curr_c + cc < C):
                        #print("out of range, continue")
                        continue
                    if (curr_r+rr, curr_c+cc) in intersection_points:
                        #print("looking back toward intersection point, continue")
                        continue
                    if (    curr_G[curr_r+rr][curr_c+cc] == "."
                            or curr_G[curr_r+rr][curr_c+cc] == ">"
                            or curr_G[curr_r+rr][curr_c+cc] == "<"
                            or curr_G[curr_r+rr][curr_c+cc] == "^"
                            or curr_G[curr_r+rr][curr_c+cc] == "v"):

                        almost_end = (curr_r, curr_c)
                        curr_r, curr_c = curr_r + rr, curr_c + cc
                        curr_G[curr_r][curr_c] = "#"
                        num_steps += 1
                        #print("stepped", rr, cc, "to", curr_r, curr_c)
                        break
                    #else:
                    #    print("hit wall at", curr_r+rr, curr_c+cc, curr_G[curr_r+rr][curr_c+cc])

                if count_adjacent_intersections((curr_r, curr_c)) == 1 and (curr_r, curr_c) != (r, c):
                    #print("done finding path", curr_r, curr_c)
                    break
                    
            curr_teleport_end = (curr_r, curr_c)
            teleportations[curr_teleport_start] = (curr_teleport_end, almost_end, num_steps)
        
for k,v in teleportations.items():
    print(k, ":", v[0], v[1], v[2])
# Out:
# (1, 1) : (4, 7) (3, 7) 17
# (4, 7) : (1, 1) (1, 2) 17
# (5, 8) : (15, 40) (15, 39) 302
# (5, 58) : (15, 42) (15, 43) 150
# (5, 60) : (7, 88) (7, 87) 134
# (6, 7) : (28, 13) (27, 13) 152
# (6, 59) : (32, 63) (31, 63) 154
# (7, 88) : (5, 60) (5, 61) 134
# (7, 90) : (11, 108) (11, 107) 126
# (8, 89) : (34, 81) (33, 81) 126
# (11, 108) : (7, 90) (7, 91) 126
# (11, 110) : (40, 137) (39, 137) 484
# (12, 109) : (28, 107) (27, 107) 66
# (15, 40) : (5, 8) (5, 9) 302
# (15, 42) : (5, 58) (5, 57) 150
# (16, 41) : (34, 33) (33, 33) 86
# (28, 13) : (6, 7) (7, 7) 152
# (28, 107) : (12, 109) (13, 109) 66
# (29, 14) : (35, 32) (35, 31) 60
# (29, 106) : (35, 82) (35, 83) 142
# (29, 108) : (41, 136) (41, 135) 220
# (30, 13) : (56, 17) (55, 17) 274
# (30, 107) : (54, 103) (53, 103) 168
# (32, 63) : (6, 59) (7, 59) 154
# (33, 62) : (35, 34) (35, 35) 202
# (33, 64) : (35, 80) (35, 79) 102
# (34, 33) : (16, 41) (17, 41) 86
# (34, 63) : (54, 57) (53, 57) 122
# (34, 81) : (8, 89) (9, 89) 126
# (35, 32) : (29, 14) (29, 15) 60
# (35, 34) : (33, 62) (33, 61) 202
# (35, 80) : (33, 64) (33, 65) 102
# (35, 82) : (29, 106) (29, 105) 142
# (36, 33) : (58, 31) (57, 31) 148
# (36, 81) : (58, 75) (57, 75) 120
# (40, 137) : (11, 110) (11, 111) 484
# (41, 136) : (29, 108) (29, 109) 220
# (42, 137) : (56, 137) (55, 137) 46
# (54, 57) : (34, 63) (35, 63) 122
# (54, 103) : (30, 107) (31, 107) 168
# (55, 56) : (59, 32) (59, 33) 148
# (55, 58) : (59, 74) (59, 73) 132
# (55, 102) : (59, 76) (59, 77) 162
# (55, 104) : (57, 136) (57, 135) 186
# (56, 17) : (30, 13) (31, 13) 274
# (56, 57) : (82, 57) (81, 57) 142
# (56, 103) : (78, 109) (77, 109) 148
# (56, 137) : (42, 137) (43, 137) 46
# (57, 18) : (59, 30) (59, 29) 126
# (57, 136) : (55, 104) (55, 105) 186
# (58, 17) : (86, 11) (85, 11) 306
# (58, 31) : (36, 33) (37, 33) 148
# (58, 75) : (36, 81) (37, 81) 120
# (58, 137) : (78, 137) (77, 137) 100
# (59, 30) : (57, 18) (57, 19) 126
# (59, 32) : (55, 56) (55, 55) 148
# (59, 74) : (55, 58) (55, 59) 132
# (59, 76) : (55, 102) (55, 101) 162
# (60, 31) : (88, 43) (87, 43) 176
# (60, 75) : (82, 87) (81, 87) 130
# (78, 109) : (56, 103) (57, 103) 148
# (78, 137) : (58, 137) (59, 137) 100
# (79, 108) : (83, 88) (83, 89) 116
# (79, 110) : (79, 136) (79, 135) 126
# (79, 136) : (79, 110) (79, 111) 126
# (80, 109) : (104, 99) (103, 99) 134
# (80, 137) : (102, 127) (101, 127) 160
# (82, 57) : (56, 57) (57, 57) 142
# (82, 87) : (60, 75) (61, 75) 130
# (83, 56) : (89, 44) (89, 45) 34
# (83, 58) : (83, 86) (83, 85) 192
# (83, 86) : (83, 58) (83, 59) 192
# (83, 88) : (79, 108) (79, 107) 116
# (84, 57) : (106, 53) (105, 53) 122
# (84, 87) : (104, 87) (103, 87) 96
# (86, 11) : (58, 17) (59, 17) 306
# (87, 12) : (89, 42) (89, 41) 216
# (88, 11) : (110, 17) (109, 17) 208
# (88, 43) : (60, 31) (61, 31) 176
# (89, 42) : (87, 12) (87, 13) 216
# (89, 44) : (83, 56) (83, 55) 34
# (90, 43) : (100, 41) (99, 41) 40
# (100, 41) : (90, 43) (91, 43) 40
# (101, 40) : (111, 18) (111, 19) 112
# (101, 42) : (107, 52) (107, 51) 52
# (102, 41) : (132, 39) (131, 39) 196
# (102, 127) : (80, 137) (81, 137) 160
# (103, 126) : (105, 100) (105, 101) 204
# (104, 87) : (84, 87) (85, 87) 96
# (104, 99) : (80, 109) (81, 109) 134
# (104, 127) : (130, 137) (129, 137) 188
# (105, 86) : (107, 54) (107, 55) 186
# (105, 88) : (105, 98) (105, 97) 58
# (105, 98) : (105, 88) (105, 89) 58
# (105, 100) : (103, 126) (103, 125) 204
# (106, 53) : (84, 57) (85, 57) 122
# (106, 87) : (124, 83) (123, 83) 66
# (106, 99) : (122, 113) (121, 113) 102
# (107, 52) : (101, 42) (101, 43) 52
# (107, 54) : (105, 86) (105, 85) 186
# (108, 53) : (124, 63) (123, 63) 110
# (110, 17) : (88, 11) (89, 11) 208
# (111, 18) : (101, 40) (101, 39) 112
# (112, 17) : (133, 38) (133, 37) 402
# (122, 113) : (106, 99) (107, 99) 102
# (123, 112) : (125, 84) (125, 85) 206
# (123, 114) : (131, 136) (131, 135) 254
# (124, 63) : (108, 53) (109, 53) 110
# (124, 83) : (106, 87) (107, 87) 66
# (125, 62) : (133, 40) (133, 41) 242
# (125, 64) : (125, 82) (125, 81) 278
# (125, 82) : (125, 64) (125, 65) 278
# (125, 84) : (123, 112) (123, 111) 206
# (130, 137) : (104, 127) (105, 127) 188
# (131, 136) : (123, 114) (123, 115) 254
# (132, 39) : (102, 41) (103, 41) 196
# (132, 137) : (139, 139) (139, 138) 25
# (133, 38) : (112, 17) (113, 17) 402
# (133, 40) : (125, 62) (125, 61) 242
# (139, 139) : (132, 137) (133, 137) 25

# %%
num_states_considered = 0
longest_dist = -1

min_curr_acc_heat_losses = {}

q = []
heapq.heapify(q)

# pos, visited_poses
first_visited_poses = set()
first_visited_poses.add((0, 1))
first_state = ((0,1), first_visited_poses, 0)
#first_state = ((0,1), [(0,1)])

heapq.heappush(q, first_state)

use_teleport = True

while len(q) > 0:

    current_state = heapq.heappop(q)

    curr_pos, curr_visited_poses, curr_extra_steps = current_state
    r, c = curr_pos

    #print(current_state)

    #print("curr_visited_poses:", curr_visited_poses)
    
    num_states_considered += 1

    if num_states_considered % 1000000 == 0:
        print(f"    {num_states_considered} states considered, longest_dist: {longest_dist}")

    if curr_pos == (R-1, C-2):
        longest_dist = max(longest_dist, len(curr_visited_poses) + curr_extra_steps)
        continue

    # seems like there aren't any dead ends, so this is useless
    #possible_poses = [(r-1, c), (r+1, c), (r, c-1), (r, c+1)]
    #barriers = [G_with_dead_ends_closed[pos[0]][pos[1]] for pos in possible_poses]
    #if possible_poses.count("#") == 3: # dead end
    #    G_with_dead_ends_closed[r][c] = "#"
    #    print("closing dead end")
    #    continue

    teleported = False
    if curr_pos in teleportations:
        next_pos, almost_end, additional_steps = teleportations[curr_pos]
        if not (next_pos in curr_visited_poses):
            next_visited_poses = set(curr_visited_poses)
            next_visited_poses.add(curr_pos)
            next_visited_poses.add(almost_end)
            next_visited_poses.add(next_pos)
            #print("teleporting from", curr_pos, "to", next_pos)
            #print("next_visited_poses:", next_visited_poses)


            next_extra_steps = curr_extra_steps + additional_steps - 2

            next_state = (next_pos, next_visited_poses, next_extra_steps)

            heapq.heappush(q, next_state)
            teleported = True
            
    if not teleported:
        for next_dir in [(-1, 0), (1, 0), (0, -1), (0, 1)]:

            next_pos = (r + next_dir[0], c + next_dir[1])

            if G[next_pos[0]][next_pos[1]] == "#":
                continue

            if next_pos in curr_visited_poses:
                continue
        
            # seems like using an array isn't faster than using a set
            #next_visited_poses = curr_visited_poses + [next_pos]

            next_visited_poses = set(curr_visited_poses)
            next_visited_poses.add(next_pos)

            next_state = (next_pos, next_visited_poses, curr_extra_steps)
            heapq.heappush(q, next_state)

print("num states checked:", num_states_considered)

print(f"part 2:    all states exhausted, longest_dist = {longest_dist-1}")
# Out:
#     1000000 states considered, longest_dist: -1
#     2000000 states considered, longest_dist: -1
#     3000000 states considered, longest_dist: -1
#     4000000 states considered, longest_dist: -1
#     5000000 states considered, longest_dist: -1
#     6000000 states considered, longest_dist: -1
#     7000000 states considered, longest_dist: -1
#     8000000 states considered, longest_dist: -1
#     9000000 states considered, longest_dist: -1
#     10000000 states considered, longest_dist: -1
#     11000000 states considered, longest_dist: -1
#     12000000 states considered, longest_dist: -1
#     13000000 states considered, longest_dist: -1
#     14000000 states considered, longest_dist: -1
#     15000000 states considered, longest_dist: -1
#     16000000 states considered, longest_dist: -1
#     17000000 states considered, longest_dist: -1
#     18000000 states considered, longest_dist: -1
#     19000000 states considered, longest_dist: -1
#     20000000 states considered, longest_dist: -1
#     21000000 states considered, longest_dist: -1
#     22000000 states considered, longest_dist: -1
#     23000000 states considered, longest_dist: -1
#     24000000 states considered, longest_dist: -1
#     25000000 states considered, longest_dist: -1
#     26000000 states considered, longest_dist: -1
#     27000000 states considered, longest_dist: -1
#     28000000 states considered, longest_dist: -1
#     29000000 states considered, longest_dist: -1
#     30000000 states considered, longest_dist: -1
#     31000000 states considered, longest_dist: -1
#     32000000 states considered, longest_dist: -1
#     33000000 states considered, longest_dist: -1
#     34000000 states considered, longest_dist: -1
#     35000000 states considered, longest_dist: -1
#     36000000 states considered, longest_dist: -1
#     37000000 states considered, longest_dist: -1
#     38000000 states considered, longest_dist: -1
#     39000000 states considered, longest_dist: -1
#     40000000 states considered, longest_dist: -1
#     41000000 states considered, longest_dist: -1
#     42000000 states considered, longest_dist: -1
#     43000000 states considered, longest_dist: -1
#     44000000 states considered, longest_dist: -1
#     45000000 states considered, longest_dist: -1
#     46000000 states considered, longest_dist: -1
#     47000000 states considered, longest_dist: -1
#     48000000 states considered, longest_dist: -1
#     49000000 states considered, longest_dist: -1
#     50000000 states considered, longest_dist: -1
#     51000000 states considered, longest_dist: -1
#     52000000 states considered, longest_dist: -1
#     53000000 states considered, longest_dist: -1
#     54000000 states considered, longest_dist: -1
#     55000000 states considered, longest_dist: -1
#     56000000 states considered, longest_dist: -1
#     57000000 states considered, longest_dist: -1
#     58000000 states considered, longest_dist: -1
#     59000000 states considered, longest_dist: -1
#     60000000 states considered, longest_dist: -1
#     61000000 states considered, longest_dist: -1
#     62000000 states considered, longest_dist: -1
#     63000000 states considered, longest_dist: -1
#     64000000 states considered, longest_dist: -1
#     65000000 states considered, longest_dist: -1
#     66000000 states considered, longest_dist: -1
#     67000000 states considered, longest_dist: -1
#     68000000 states considered, longest_dist: -1
#     69000000 states considered, longest_dist: -1
#     70000000 states considered, longest_dist: -1
#     71000000 states considered, longest_dist: -1
#     72000000 states considered, longest_dist: -1
#     73000000 states considered, longest_dist: -1
#     74000000 states considered, longest_dist: -1
#     75000000 states considered, longest_dist: -1
#     76000000 states considered, longest_dist: -1
#     77000000 states considered, longest_dist: -1
#     78000000 states considered, longest_dist: -1
#     79000000 states considered, longest_dist: -1
#     80000000 states considered, longest_dist: -1
#     81000000 states considered, longest_dist: -1
#     82000000 states considered, longest_dist: -1
#     83000000 states considered, longest_dist: -1
#     84000000 states considered, longest_dist: -1
#     85000000 states considered, longest_dist: -1
#     86000000 states considered, longest_dist: -1
#     87000000 states considered, longest_dist: -1
#     88000000 states considered, longest_dist: -1
#     89000000 states considered, longest_dist: -1
#     90000000 states considered, longest_dist: -1
#     91000000 states considered, longest_dist: -1
#     92000000 states considered, longest_dist: -1
#     93000000 states considered, longest_dist: -1
#     94000000 states considered, longest_dist: -1
#     95000000 states considered, longest_dist: -1
#     96000000 states considered, longest_dist: -1
#     97000000 states considered, longest_dist: -1
#     98000000 states considered, longest_dist: -1
#     99000000 states considered, longest_dist: -1
#     100000000 states considered, longest_dist: -1
#     101000000 states considered, longest_dist: -1
#     102000000 states considered, longest_dist: -1
#     103000000 states considered, longest_dist: -1
#     104000000 states considered, longest_dist: -1
#     105000000 states considered, longest_dist: -1
#     106000000 states considered, longest_dist: -1
#     107000000 states considered, longest_dist: -1
#     108000000 states considered, longest_dist: -1
#     109000000 states considered, longest_dist: -1
#     110000000 states considered, longest_dist: -1
#     111000000 states considered, longest_dist: -1
#     112000000 states considered, longest_dist: -1
#     113000000 states considered, longest_dist: -1
#     114000000 states considered, longest_dist: -1
#     115000000 states considered, longest_dist: -1
#     116000000 states considered, longest_dist: -1
#     117000000 states considered, longest_dist: -1
#     118000000 states considered, longest_dist: -1
#     119000000 states considered, longest_dist: -1
#     120000000 states considered, longest_dist: -1
#     121000000 states considered, longest_dist: -1
#     122000000 states considered, longest_dist: -1
#     123000000 states considered, longest_dist: -1
#     124000000 states considered, longest_dist: -1
#     125000000 states considered, longest_dist: -1
#     126000000 states considered, longest_dist: -1
#     127000000 states considered, longest_dist: -1
#     128000000 states considered, longest_dist: -1
#     129000000 states considered, longest_dist: -1
#     130000000 states considered, longest_dist: -1
#     131000000 states considered, longest_dist: -1
#     132000000 states considered, longest_dist: -1
#     133000000 states considered, longest_dist: -1
#     134000000 states considered, longest_dist: -1
#     135000000 states considered, longest_dist: -1
#     136000000 states considered, longest_dist: -1
#     137000000 states considered, longest_dist: -1
#     138000000 states considered, longest_dist: -1
#     139000000 states considered, longest_dist: -1
#     140000000 states considered, longest_dist: -1
#     141000000 states considered, longest_dist: -1
#     142000000 states considered, longest_dist: -1
#     143000000 states considered, longest_dist: -1
#     144000000 states considered, longest_dist: -1
#     145000000 states considered, longest_dist: -1
#     146000000 states considered, longest_dist: -1
#     147000000 states considered, longest_dist: -1
#     148000000 states considered, longest_dist: -1
#     149000000 states considered, longest_dist: -1
#     150000000 states considered, longest_dist: -1
#     151000000 states considered, longest_dist: -1
#     152000000 states considered, longest_dist: -1
#     153000000 states considered, longest_dist: -1
#     154000000 states considered, longest_dist: -1
#     155000000 states considered, longest_dist: -1
#     156000000 states considered, longest_dist: -1
#     157000000 states considered, longest_dist: -1
#     158000000 states considered, longest_dist: -1
#     159000000 states considered, longest_dist: -1
#     160000000 states considered, longest_dist: -1
#     161000000 states considered, longest_dist: -1
#     162000000 states considered, longest_dist: -1
#     163000000 states considered, longest_dist: -1
#     164000000 states considered, longest_dist: -1
#     165000000 states considered, longest_dist: -1
#     166000000 states considered, longest_dist: -1
#     167000000 states considered, longest_dist: -1
#     168000000 states considered, longest_dist: -1
#     169000000 states considered, longest_dist: -1
#     170000000 states considered, longest_dist: -1
#     171000000 states considered, longest_dist: -1
#     172000000 states considered, longest_dist: -1
#     173000000 states considered, longest_dist: -1
#     174000000 states considered, longest_dist: -1
#     175000000 states considered, longest_dist: -1
#     176000000 states considered, longest_dist: 6235
# num states checked: 176522692
# part 2:    all states exhausted, longest_dist = 6246

# %%
"""
#.#####################
#.......#########...###
#######.#########.#.###
###.....#.>.>.###.#.###
###v#####.#v#.###.#.###
###.>...#.#.#.....#...#
###v###.#.#.#########.#
###...#.#.#.......#...#
#####.#.#.#######.#.###
#.....#.#.#.......#...#
#.#####.#.#.#########v#
#.#...#...#...###...>.#
#.#.#v#######v###.###v#
#...#.>.#...>.>.#.###.#
#####v#.#.###v#.#.###.#
#.....#...#...#.#.#...#
#.#########.###.#.#.###
#...###...#...#...#.###
###.###.#.###v#####v###
#...#...#.#.>.>.#.>.###
#.###.###.#.###.#.#v###
#.....###...###...#...#
#####################.#
"""
# Out:
# '\n#.#####################\n#.......#########...###\n#######.#########.#.###\n###.....#.>.>.###.#.###\n###v#####.#v#.###.#.###\n###.>...#.#.#.....#...#\n###v###.#.#.#########.#\n###...#.#.#.......#...#\n#####.#.#.#######.#.###\n#.....#.#.#.......#...#\n#.#####.#.#.#########v#\n#.#...#...#...###...>.#\n#.#.#v#######v###.###v#\n#...#.>.#...>.>.#.###.#\n#####v#.#.###v#.#.###.#\n#.....#...#...#.#.#...#\n#.#########.###.#.#.###\n#...###...#...#...#.###\n###.###.#.###v#####v###\n#...#...#.#.>.>.#.>.###\n#.###.###.#.###.#.#v###\n#.....###...###...#...#\n#####################.#\n'

# %%
"""num_states_considered = 0
longest_dist = -1

min_curr_acc_heat_losses = {}

q = []
heapq.heapify(q)

# pos, visited_poses
first_state = ((0,1), set((0,1)))
#first_state = ((0,1), [(0,1)])

heapq.heappush(q, first_state)

while len(q) > 0:

    current_state = heapq.heappop(q)

    curr_pos, curr_visited_poses = current_state
    r, c = curr_pos
    
    num_states_considered += 1

    if num_states_considered % 1000000 == 0:
        print(f"    {num_states_considered} states considered, longest_dist: {longest_dist-2}")

    if curr_pos == (R-1, C-2):
        longest_dist = max(longest_dist, len(curr_visited_poses))
        continue

    # seems like there aren't any dead ends, so this is useless
    #possible_poses = [(r-1, c), (r+1, c), (r, c-1), (r, c+1)]
    #barriers = [G_with_dead_ends_closed[pos[0]][pos[1]] for pos in possible_poses]
    #if possible_poses.count("#") == 3: # dead end
    #    G_with_dead_ends_closed[r][c] = "#"
    #    print("closing dead end")
    #    continue

    for next_dir in [(-1, 0), (1, 0), (0, -1), (0, 1)]:

        next_pos = (r + next_dir[0], c + next_dir[1])

        if G_with_dead_ends_closed[next_pos[0]][next_pos[1]] == "#":
            continue

        if next_pos in curr_visited_poses:
            continue
    
        # seems like using an array isn't faster than using a set
        #next_visited_poses = curr_visited_poses + [next_pos]

        next_visited_poses = set(curr_visited_poses)
        next_visited_poses.add(next_pos)

        next_state = (next_pos, next_visited_poses)
        heapq.heappush(q, next_state)

print(f"part 2:    all states exhausted, longest_dist = {longest_dist-2}")

"""
# Out:
# 'num_states_considered = 0\nlongest_dist = -1\n\nmin_curr_acc_heat_losses = {}\n\nq = []\nheapq.heapify(q)\n\n# pos, visited_poses\nfirst_state = ((0,1), set((0,1)))\n#first_state = ((0,1), [(0,1)])\n\nheapq.heappush(q, first_state)\n\nwhile len(q) > 0:\n\n    current_state = heapq.heappop(q)\n\n    curr_pos, curr_visited_poses = current_state\n    r, c = curr_pos\n    \n    num_states_considered += 1\n\n    if num_states_considered % 1000000 == 0:\n        print(f"    {num_states_considered} states considered, longest_dist: {longest_dist-2}")\n\n    if curr_pos == (R-1, C-2):\n        longest_dist = max(longest_dist, len(curr_visited_poses))\n        continue\n\n    # seems like there aren\'t any dead ends, so this is useless\n    #possible_poses = [(r-1, c), (r+1, c), (r, c-1), (r, c+1)]\n    #barriers = [G_with_dead_ends_closed[pos[0]][pos[1]] for pos in possible_poses]\n    #if possible_poses.count("#") == 3: # dead end\n    #    G_with_dead_ends_closed[r][c] = "#"\n    #    print("closing dead end")\n    #    continue\n\n    for next_dir in [(-1, 0), (1, 0), (0, -1), (0, 1)]:\n\n        next_pos = (r + next_dir[0], c + next_dir[1])\n\n        if G_with_dead_ends_closed[next_pos[0]][next_pos[1]] == "#":\n            continue\n\n        if next_pos in curr_visited_poses:\n            continue\n    \n        # seems like using an array isn\'t faster than using a set\n        #next_visited_poses = curr_visited_poses + [next_pos]\n\n        next_visited_poses = set(curr_visited_poses)\n        next_visited_poses.add(next_pos)\n\n        next_state = (next_pos, next_visited_poses)\n        heapq.heappush(q, next_state)\n\nprint(f"part 2:    all states exhausted, longest_dist = {longest_dist-2}")\n\n'

# %%
# 5 million in 2 minutes
