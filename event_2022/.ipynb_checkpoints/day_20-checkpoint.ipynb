# %%
import numpy as np

from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

from queue import PriorityQueue

# %%
with open("input_day_20.txt") as file:
    
    text = file.read()

# %%
test = False
if test:

    text = """1
2
-3
3
-2
0
4"""
    
text = text.strip()

# %%
nums = [int(l) for l in text.split("\n")]

nums_ids = [(nums[i], i) for i in range(len(nums))]

# %%
#import collections
#print(len([item for item, count in collections.Counter(nums).items() if count > 1]))

# %%
def move(curr_nums_ids, num_id, test=False):
    if test:
        print("moving", num_id)
        
    num, idnum = num_id
    
    old_pos = curr_nums_ids.index(num_id)
    new_pos = (old_pos + num) % (len(curr_nums_ids) - 1) # always biased left, will never place a number on the very right
    
    if test:
        print("new pos:", new_pos)
    
    other_nums_ids = curr_nums_ids.copy()
    other_nums_ids.remove(num_id)
    
    curr_nums_ids = other_nums_ids[:new_pos] + [num_id] + other_nums_ids[new_pos:]
    
    if test:
        print(curr_nums_ids)
        
    return curr_nums_ids.copy()

# %%
curr_nums_ids = nums_ids.copy()

if test:
    print(curr_nums_ids)

for num_id in nums_ids:
    
    curr_nums_ids = move(curr_nums_ids, num_id, test=test)
    
mixed_nums_ids = curr_nums_ids

mixed_nums = [x[0] for x in curr_nums_ids]
# Out:
# [(1, 0), (2, 1), (-3, 2), (3, 3), (-2, 4), (0, 5), (4, 6)]
# moving (1, 0)
# new pos: 1
# [(2, 1), (1, 0), (-3, 2), (3, 3), (-2, 4), (0, 5), (4, 6)]
# moving (2, 1)
# new pos: 2
# [(1, 0), (-3, 2), (2, 1), (3, 3), (-2, 4), (0, 5), (4, 6)]
# moving (-3, 2)
# new pos: 4
# [(1, 0), (2, 1), (3, 3), (-2, 4), (-3, 2), (0, 5), (4, 6)]
# moving (3, 3)
# new pos: 5
# [(1, 0), (2, 1), (-2, 4), (-3, 2), (0, 5), (3, 3), (4, 6)]
# moving (-2, 4)
# new pos: 0
# [(-2, 4), (1, 0), (2, 1), (-3, 2), (0, 5), (3, 3), (4, 6)]
# moving (0, 5)
# new pos: 4
# [(-2, 4), (1, 0), (2, 1), (-3, 2), (0, 5), (3, 3), (4, 6)]
# moving (4, 6)
# new pos: 4
# [(-2, 4), (1, 0), (2, 1), (-3, 2), (4, 6), (0, 5), (3, 3)]

# %%
print(len(nums), len(mixed_nums))

start_index = mixed_nums.index(0)

print(mixed_nums[(start_index + 1000) % len(nums)], mixed_nums[(start_index + 2000) % len(nums)], mixed_nums[(start_index + 3000) % len(nums)])
print(mixed_nums[(start_index + 1000) % len(nums)] + mixed_nums[(start_index + 2000) % len(nums)] + mixed_nums[(start_index + 3000) % len(nums)])

# 9505 is too low
# -4908 is wrong
# Out:
# 7 7
# 4 -3 2
# 3

# %%
decrypted_nums_ids = [(x[0] * 811589153, x[1]) for x in nums_ids]

ten_x_nums_ids = []
for i in range(10):
    ten_x_nums_ids += decrypted_nums_ids
    
curr_nums_ids = decrypted_nums_ids.copy()

for num_id in ten_x_nums_ids:
    
    curr_nums_ids = move(curr_nums_ids, num_id, test=test)
    
mixed_nums = [x[0] for x in curr_nums_ids]
# Out:
# moving (811589153, 0)
# new pos: 5
# [(1623178306, 1), (-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (1623178306, 1)
# new pos: 4
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (-2434767459, 2)
# new pos: 3
# [(2434767459, 3), (-1623178306, 4), (0, 5), (-2434767459, 2), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (2434767459, 3)
# new pos: 3
# [(-1623178306, 4), (0, 5), (-2434767459, 2), (2434767459, 3), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (-1623178306, 4)
# new pos: 2
# [(0, 5), (-2434767459, 2), (-1623178306, 4), (2434767459, 3), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (-2434767459, 2), (-1623178306, 4), (2434767459, 3), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (3246356612, 6)
# new pos: 2
# [(0, 5), (-2434767459, 2), (3246356612, 6), (-1623178306, 4), (2434767459, 3), (1623178306, 1), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(0, 5), (-2434767459, 2), (3246356612, 6), (-1623178306, 4), (2434767459, 3), (811589153, 0), (1623178306, 1)]
# moving (1623178306, 1)
# new pos: 4
# [(0, 5), (-2434767459, 2), (3246356612, 6), (-1623178306, 4), (1623178306, 1), (2434767459, 3), (811589153, 0)]
# moving (-2434767459, 2)
# new pos: 4
# [(0, 5), (3246356612, 6), (-1623178306, 4), (1623178306, 1), (-2434767459, 2), (2434767459, 3), (811589153, 0)]
# moving (2434767459, 3)
# new pos: 2
# [(0, 5), (3246356612, 6), (2434767459, 3), (-1623178306, 4), (1623178306, 1), (-2434767459, 2), (811589153, 0)]
# moving (-1623178306, 4)
# new pos: 5
# [(0, 5), (3246356612, 6), (2434767459, 3), (1623178306, 1), (-2434767459, 2), (-1623178306, 4), (811589153, 0)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (3246356612, 6), (2434767459, 3), (1623178306, 1), (-2434767459, 2), (-1623178306, 4), (811589153, 0)]
# moving (3246356612, 6)
# new pos: 3
# [(0, 5), (2434767459, 3), (1623178306, 1), (3246356612, 6), (-2434767459, 2), (-1623178306, 4), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(0, 5), (2434767459, 3), (1623178306, 1), (3246356612, 6), (-2434767459, 2), (811589153, 0), (-1623178306, 4)]
# moving (1623178306, 1)
# new pos: 0
# [(1623178306, 1), (0, 5), (2434767459, 3), (3246356612, 6), (-2434767459, 2), (811589153, 0), (-1623178306, 4)]
# moving (-2434767459, 2)
# new pos: 1
# [(1623178306, 1), (-2434767459, 2), (0, 5), (2434767459, 3), (3246356612, 6), (811589153, 0), (-1623178306, 4)]
# moving (2434767459, 3)
# new pos: 0
# [(2434767459, 3), (1623178306, 1), (-2434767459, 2), (0, 5), (3246356612, 6), (811589153, 0), (-1623178306, 4)]
# moving (-1623178306, 4)
# new pos: 2
# [(2434767459, 3), (1623178306, 1), (-1623178306, 4), (-2434767459, 2), (0, 5), (3246356612, 6), (811589153, 0)]
# moving (0, 5)
# new pos: 4
# [(2434767459, 3), (1623178306, 1), (-1623178306, 4), (-2434767459, 2), (0, 5), (3246356612, 6), (811589153, 0)]
# moving (3246356612, 6)
# new pos: 1
# [(2434767459, 3), (3246356612, 6), (1623178306, 1), (-1623178306, 4), (-2434767459, 2), (0, 5), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(2434767459, 3), (3246356612, 6), (1623178306, 1), (-1623178306, 4), (-2434767459, 2), (811589153, 0), (0, 5)]
# moving (1623178306, 1)
# new pos: 0
# [(1623178306, 1), (2434767459, 3), (3246356612, 6), (-1623178306, 4), (-2434767459, 2), (811589153, 0), (0, 5)]
# moving (-2434767459, 2)
# new pos: 1
# [(1623178306, 1), (-2434767459, 2), (2434767459, 3), (3246356612, 6), (-1623178306, 4), (811589153, 0), (0, 5)]
# moving (2434767459, 3)
# new pos: 5
# [(1623178306, 1), (-2434767459, 2), (3246356612, 6), (-1623178306, 4), (811589153, 0), (2434767459, 3), (0, 5)]
# moving (-1623178306, 4)
# new pos: 5
# [(1623178306, 1), (-2434767459, 2), (3246356612, 6), (811589153, 0), (2434767459, 3), (-1623178306, 4), (0, 5)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (1623178306, 1), (-2434767459, 2), (3246356612, 6), (811589153, 0), (2434767459, 3), (-1623178306, 4)]
# moving (3246356612, 6)
# new pos: 5
# [(0, 5), (1623178306, 1), (-2434767459, 2), (811589153, 0), (2434767459, 3), (3246356612, 6), (-1623178306, 4)]
# moving (811589153, 0)
# new pos: 2
# [(0, 5), (1623178306, 1), (811589153, 0), (-2434767459, 2), (2434767459, 3), (3246356612, 6), (-1623178306, 4)]
# moving (1623178306, 1)
# new pos: 5
# [(0, 5), (811589153, 0), (-2434767459, 2), (2434767459, 3), (3246356612, 6), (1623178306, 1), (-1623178306, 4)]
# moving (-2434767459, 2)
# new pos: 5
# [(0, 5), (811589153, 0), (2434767459, 3), (3246356612, 6), (1623178306, 1), (-2434767459, 2), (-1623178306, 4)]
# moving (2434767459, 3)
# new pos: 5
# [(0, 5), (811589153, 0), (3246356612, 6), (1623178306, 1), (-2434767459, 2), (2434767459, 3), (-1623178306, 4)]
# moving (-1623178306, 4)
# new pos: 2
# [(0, 5), (811589153, 0), (-1623178306, 4), (3246356612, 6), (1623178306, 1), (-2434767459, 2), (2434767459, 3)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (811589153, 0), (-1623178306, 4), (3246356612, 6), (1623178306, 1), (-2434767459, 2), (2434767459, 3)]
# moving (3246356612, 6)
# new pos: 5
# [(0, 5), (811589153, 0), (-1623178306, 4), (1623178306, 1), (-2434767459, 2), (3246356612, 6), (2434767459, 3)]
# moving (811589153, 0)
# new pos: 0
# [(811589153, 0), (0, 5), (-1623178306, 4), (1623178306, 1), (-2434767459, 2), (3246356612, 6), (2434767459, 3)]
# moving (1623178306, 1)
# new pos: 1
# [(811589153, 0), (1623178306, 1), (0, 5), (-1623178306, 4), (-2434767459, 2), (3246356612, 6), (2434767459, 3)]
# moving (-2434767459, 2)
# new pos: 1
# [(811589153, 0), (-2434767459, 2), (1623178306, 1), (0, 5), (-1623178306, 4), (3246356612, 6), (2434767459, 3)]
# moving (2434767459, 3)
# new pos: 3
# [(811589153, 0), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (0, 5), (-1623178306, 4), (3246356612, 6)]
# moving (-1623178306, 4)
# new pos: 1
# [(811589153, 0), (-1623178306, 4), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (0, 5), (3246356612, 6)]
# moving (0, 5)
# new pos: 5
# [(811589153, 0), (-1623178306, 4), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (0, 5), (3246356612, 6)]
# moving (3246356612, 6)
# new pos: 2
# [(811589153, 0), (-1623178306, 4), (3246356612, 6), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (0, 5)]
# moving (811589153, 0)
# new pos: 5
# [(-1623178306, 4), (3246356612, 6), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (811589153, 0), (0, 5)]
# moving (1623178306, 1)
# new pos: 1
# [(-1623178306, 4), (1623178306, 1), (3246356612, 6), (-2434767459, 2), (2434767459, 3), (811589153, 0), (0, 5)]
# moving (-2434767459, 2)
# new pos: 0
# [(-2434767459, 2), (-1623178306, 4), (1623178306, 1), (3246356612, 6), (2434767459, 3), (811589153, 0), (0, 5)]
# moving (2434767459, 3)
# new pos: 1
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (1623178306, 1), (3246356612, 6), (811589153, 0), (0, 5)]
# moving (-1623178306, 4)
# new pos: 4
# [(-2434767459, 2), (2434767459, 3), (1623178306, 1), (3246356612, 6), (-1623178306, 4), (811589153, 0), (0, 5)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (-2434767459, 2), (2434767459, 3), (1623178306, 1), (3246356612, 6), (-1623178306, 4), (811589153, 0)]
# moving (3246356612, 6)
# new pos: 0
# [(3246356612, 6), (0, 5), (-2434767459, 2), (2434767459, 3), (1623178306, 1), (-1623178306, 4), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(3246356612, 6), (0, 5), (-2434767459, 2), (2434767459, 3), (1623178306, 1), (811589153, 0), (-1623178306, 4)]
# moving (1623178306, 1)
# new pos: 2
# [(3246356612, 6), (0, 5), (1623178306, 1), (-2434767459, 2), (2434767459, 3), (811589153, 0), (-1623178306, 4)]
# moving (-2434767459, 2)
# new pos: 0
# [(-2434767459, 2), (3246356612, 6), (0, 5), (1623178306, 1), (2434767459, 3), (811589153, 0), (-1623178306, 4)]
# moving (2434767459, 3)
# new pos: 1
# [(-2434767459, 2), (2434767459, 3), (3246356612, 6), (0, 5), (1623178306, 1), (811589153, 0), (-1623178306, 4)]
# moving (-1623178306, 4)
# new pos: 2
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (3246356612, 6), (0, 5), (1623178306, 1), (811589153, 0)]
# moving (0, 5)
# new pos: 4
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (3246356612, 6), (0, 5), (1623178306, 1), (811589153, 0)]
# moving (3246356612, 6)
# new pos: 5
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (1623178306, 1), (3246356612, 6), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (1623178306, 1), (811589153, 0), (3246356612, 6)]
# moving (1623178306, 1)
# new pos: 2
# [(-2434767459, 2), (2434767459, 3), (1623178306, 1), (-1623178306, 4), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (-2434767459, 2)
# new pos: 3
# [(2434767459, 3), (1623178306, 1), (-1623178306, 4), (-2434767459, 2), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (2434767459, 3)
# new pos: 3
# [(1623178306, 1), (-1623178306, 4), (-2434767459, 2), (2434767459, 3), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (-1623178306, 4)
# new pos: 3
# [(1623178306, 1), (-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (0, 5)
# new pos: 4
# [(1623178306, 1), (-2434767459, 2), (2434767459, 3), (-1623178306, 4), (0, 5), (811589153, 0), (3246356612, 6)]
# moving (3246356612, 6)
# new pos: 2
# [(1623178306, 1), (-2434767459, 2), (3246356612, 6), (2434767459, 3), (-1623178306, 4), (0, 5), (811589153, 0)]
# moving (811589153, 0)
# new pos: 5
# [(1623178306, 1), (-2434767459, 2), (3246356612, 6), (2434767459, 3), (-1623178306, 4), (811589153, 0), (0, 5)]
# moving (1623178306, 1)
# new pos: 4
# [(-2434767459, 2), (3246356612, 6), (2434767459, 3), (-1623178306, 4), (1623178306, 1), (811589153, 0), (0, 5)]
# moving (-2434767459, 2)
# new pos: 3
# [(3246356612, 6), (2434767459, 3), (-1623178306, 4), (-2434767459, 2), (1623178306, 1), (811589153, 0), (0, 5)]
# moving (2434767459, 3)
# new pos: 4
# [(3246356612, 6), (-1623178306, 4), (-2434767459, 2), (1623178306, 1), (2434767459, 3), (811589153, 0), (0, 5)]
# moving (-1623178306, 4)
# new pos: 3
# [(3246356612, 6), (-2434767459, 2), (1623178306, 1), (-1623178306, 4), (2434767459, 3), (811589153, 0), (0, 5)]
# moving (0, 5)
# new pos: 0
# [(0, 5), (3246356612, 6), (-2434767459, 2), (1623178306, 1), (-1623178306, 4), (2434767459, 3), (811589153, 0)]
# moving (3246356612, 6)
# new pos: 3
# [(0, 5), (-2434767459, 2), (1623178306, 1), (3246356612, 6), (-1623178306, 4), (2434767459, 3), (811589153, 0)]

# %%
start_index = mixed_nums.index(0)

print(mixed_nums[(start_index + 1000) % len(nums)], mixed_nums[(start_index + 2000) % len(nums)], mixed_nums[(start_index + 3000) % len(nums)])
print(mixed_nums[(start_index + 1000) % len(nums)] + mixed_nums[(start_index + 2000) % len(nums)] + mixed_nums[(start_index + 3000) % len(nums)])
# Out:
# 811589153 2434767459 -1623178306
# 1623178306
